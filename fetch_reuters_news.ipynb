# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import json
import time
import re
import pandas as pd
from datetime import datetime
from pathlib import Path

REQUIRED_FIELDS = ['id', 'canonical_url', 'updated_time', 'source', 'title', 'description']

def reuters_search(company: str, ticker: str, slug: str, page_size: int = 100, delay: float = 1.0, output_dir: str = "data/reuters_news"):
    filename = f"{output_dir.rstrip('/')}/{ticker}.csv"

    # check if the file exists
    if Path(filename).exists():
        print(f"Skipping {ticker}, already file exists.")
        return

    opts = Options()
    # Uncomment for silent/background scraping
    opts.add_argument("--headless=new")
    opts.add_argument("--disable-gpu")
    opts.add_argument("--no-sandbox")
    opts.add_argument("--window-size=1360,900")
    opts.add_argument("--disable-blink-features=AutomationControlled")
    opts.add_argument(
        "user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/129.0.0.0 Safari/537.36"
    )

    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=opts)

    offset = 0
    all_articles = []
    total_count = 0

    try:
        while True:
            query = (
                f'{{"arc-site":"reuters","offset":{offset},"orderby":"","size":"{page_size}",'
                f'"topic_url":"/company/{slug}/","uri":"/company/{slug}/","website":"reuters"}}'
            )
            base_api_url = f"https://www.reuters.com/pf/api/v3/content/fetch/articles-by-topic-v1?query={query}"
            driver.get(base_api_url)
            page_source = driver.page_source

            match = re.search(r"<pre>(.*?)</pre>", page_source, re.DOTALL)
            json_text = match.group(1).strip() if match else page_source

            try:
                data = json.loads(json_text)
                if not isinstance(data, dict):
                    data = {}
            except Exception as e:
                data = {}

            # safely extract articles
            articles = (data.get("result") or {}).get("articles") or []
            if not articles:
                break

            for article in articles:
                item = {}
                for field in REQUIRED_FIELDS:
                    value = article.get(field)
                    if field == "source" and isinstance(value, dict):
                        item[field] = value.get("name") or value.get("label")
                    elif field == "canonical_url":
                        item[field] = "https://www.reuters.com" + value
                    else:
                        item[field] = value
                item["company"] = company
                all_articles.append(item)

            count = len(articles)
            total_count += count
            print(f"Retrieved {count} articles at offset {offset}. Total so far: {total_count}")

            offset += page_size
            time.sleep(delay)

    finally:
        driver.quit()

    df = pd.DataFrame(all_articles)
    if not df.empty:
        df["updated_time"] = pd.to_datetime(df["updated_time"], errors="coerce", utc=True)
        df = df.sort_values("updated_time", ascending=False)

        # Save to CSV
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        df.to_csv(filename, index=False, encoding="utf-8-sig")
        print(f"Completed {ticker}, Saved {len(df)} articles for {company} → {filename}")
    else:
        print(f"No data to save for {company}.")

    return df

# %%
sp_100_tickers = pd.read_csv("data/sp100_tickers.csv")

for _, company_data in sp_100_tickers.iterrows():
    df = reuters_search(
        company=company_data['Name'], 
        ticker=company_data['Symbol'], 
        slug=company_data['Reuters_Company_ID'], 
        page_size=100)
# Out:
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 100 articles at offset 700. Total so far: 800
# Retrieved 100 articles at offset 800. Total so far: 900
# Retrieved 100 articles at offset 900. Total so far: 1000
# Retrieved 100 articles at offset 1000. Total so far: 1100
# Retrieved 100 articles at offset 1100. Total so far: 1200
# Retrieved 100 articles at offset 1200. Total so far: 1300
# Retrieved 100 articles at offset 1300. Total so far: 1400
# Retrieved 100 articles at offset 1400. Total so far: 1500
# Retrieved 100 articles at offset 1500. Total so far: 1600
# Retrieved 100 articles at offset 1600. Total so far: 1700
# Retrieved 100 articles at offset 1700. Total so far: 1800
# Retrieved 100 articles at offset 1800. Total so far: 1900
# Retrieved 100 articles at offset 1900. Total so far: 2000
# Retrieved 100 articles at offset 2000. Total so far: 2100
# Retrieved 100 articles at offset 2100. Total so far: 2200
# Retrieved 100 articles at offset 2200. Total so far: 2300
# Retrieved 100 articles at offset 2300. Total so far: 2400
# Retrieved 100 articles at offset 2400. Total so far: 2500
# Retrieved 100 articles at offset 2500. Total so far: 2600
# Retrieved 100 articles at offset 2600. Total so far: 2700
# Retrieved 100 articles at offset 2700. Total so far: 2800
# Retrieved 100 articles at offset 2800. Total so far: 2900
# Retrieved 100 articles at offset 2900. Total so far: 3000
# Retrieved 100 articles at offset 3000. Total so far: 3100
# Retrieved 100 articles at offset 3100. Total so far: 3200
# Retrieved 100 articles at offset 3200. Total so far: 3300
# Retrieved 100 articles at offset 3300. Total so far: 3400
# Retrieved 100 articles at offset 3400. Total so far: 3500
# Retrieved 100 articles at offset 3500. Total so far: 3600
# Retrieved 100 articles at offset 3600. Total so far: 3700
# Retrieved 100 articles at offset 3700. Total so far: 3800
# Retrieved 100 articles at offset 3800. Total so far: 3900
# Retrieved 100 articles at offset 3900. Total so far: 4000
# Retrieved 100 articles at offset 4000. Total so far: 4100
# Retrieved 100 articles at offset 4100. Total so far: 4200
# Retrieved 100 articles at offset 4200. Total so far: 4300
# Retrieved 100 articles at offset 4300. Total so far: 4400
# Retrieved 100 articles at offset 4400. Total so far: 4500
# Retrieved 100 articles at offset 4500. Total so far: 4600
# Retrieved 100 articles at offset 4600. Total so far: 4700
# Retrieved 100 articles at offset 4700. Total so far: 4800
# Retrieved 100 articles at offset 4800. Total so far: 4900
# Retrieved 100 articles at offset 4900. Total so far: 5000
# Retrieved 100 articles at offset 5000. Total so far: 5100
# Retrieved 99 articles at offset 5100. Total so far: 5199
# Retrieved 100 articles at offset 5200. Total so far: 5299
# Retrieved 99 articles at offset 5300. Total so far: 5398
# Retrieved 100 articles at offset 5400. Total so far: 5498
# Retrieved 100 articles at offset 5500. Total so far: 5598
# Retrieved 99 articles at offset 5600. Total so far: 5697
# Retrieved 99 articles at offset 5700. Total so far: 5796
# Retrieved 100 articles at offset 5800. Total so far: 5896
# Retrieved 100 articles at offset 5900. Total so far: 5996
# Retrieved 99 articles at offset 6000. Total so far: 6095
# Retrieved 99 articles at offset 6100. Total so far: 6194
# Retrieved 98 articles at offset 6200. Total so far: 6292
# Retrieved 99 articles at offset 6300. Total so far: 6391
# Retrieved 100 articles at offset 6400. Total so far: 6491
# Retrieved 99 articles at offset 6500. Total so far: 6590
# Retrieved 100 articles at offset 6600. Total so far: 6690
# Retrieved 100 articles at offset 6700. Total so far: 6790
# Retrieved 98 articles at offset 6800. Total so far: 6888
# Retrieved 100 articles at offset 6900. Total so far: 6988
# Retrieved 100 articles at offset 7000. Total so far: 7088
# Retrieved 100 articles at offset 7100. Total so far: 7188
# Retrieved 100 articles at offset 7200. Total so far: 7288
# Retrieved 100 articles at offset 7300. Total so far: 7388
# Retrieved 45 articles at offset 7400. Total so far: 7433
# Completed AAPL, Saved 7433 articles for Apple Inc → data/reuters_news/AAPL.csv
# Skipping ABBV, already file exists.
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 68 articles at offset 300. Total so far: 368
# Completed ABT, Saved 368 articles for Abbott Laboratories → data/reuters_news/ABT.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 89 articles at offset 100. Total so far: 189
# Completed ACN, Saved 189 articles for Accenture → data/reuters_news/ACN.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 82 articles at offset 200. Total so far: 282
# Completed ADBE, Saved 282 articles for Adobe Inc → data/reuters_news/ADBE.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 66 articles at offset 100. Total so far: 166
# Completed AIG, Saved 166 articles for American International Group → data/reuters_news/AIG.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 100 articles at offset 700. Total so far: 800
# Retrieved 100 articles at offset 800. Total so far: 900
# Retrieved 100 articles at offset 900. Total so far: 1000
# Retrieved 64 articles at offset 1000. Total so far: 1064
# Completed AMD, Saved 1064 articles for Advanced Micro Devices → data/reuters_news/AMD.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 49 articles at offset 300. Total so far: 349
# Completed AMGN, Saved 349 articles for Amgen → data/reuters_news/AMGN.csv
# Retrieved 61 articles at offset 0. Total so far: 61
# Completed AMT, Saved 61 articles for American Tower → data/reuters_news/AMT.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 100 articles at offset 700. Total so far: 800
# Retrieved 100 articles at offset 800. Total so far: 900
# Retrieved 100 articles at offset 900. Total so far: 1000
# Retrieved 100 articles at offset 1000. Total so far: 1100
# Retrieved 100 articles at offset 1100. Total so far: 1200
# Completed AMZN, Saved 1200 articles for Amazon → data/reuters_news/AMZN.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 63 articles at offset 500. Total so far: 563
# Completed AVGO, Saved 563 articles for Broadcom → data/reuters_news/AVGO.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 16 articles at offset 300. Total so far: 316
# Completed AXP, Saved 316 articles for American Express → data/reuters_news/AXP.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 100 articles at offset 700. Total so far: 800
# Retrieved 100 articles at offset 800. Total so far: 900
# Retrieved 100 articles at offset 900. Total so far: 1000
# Retrieved 100 articles at offset 1000. Total so far: 1100
# Retrieved 100 articles at offset 1100. Total so far: 1200
# Retrieved 100 articles at offset 1200. Total so far: 1300
# Retrieved 100 articles at offset 1300. Total so far: 1400
# Retrieved 100 articles at offset 1400. Total so far: 1500
# Retrieved 100 articles at offset 1500. Total so far: 1600
# Retrieved 100 articles at offset 1600. Total so far: 1700
# Retrieved 100 articles at offset 1700. Total so far: 1800
# Retrieved 100 articles at offset 1800. Total so far: 1900
# Retrieved 100 articles at offset 1900. Total so far: 2000
# Retrieved 100 articles at offset 2000. Total so far: 2100
# Retrieved 100 articles at offset 2100. Total so far: 2200
# Retrieved 100 articles at offset 2200. Total so far: 2300
# Retrieved 100 articles at offset 2300. Total so far: 2400
# Retrieved 100 articles at offset 2400. Total so far: 2500
# Retrieved 100 articles at offset 2500. Total so far: 2600
# Retrieved 100 articles at offset 2600. Total so far: 2700
# Retrieved 100 articles at offset 2700. Total so far: 2800
# Retrieved 100 articles at offset 2800. Total so far: 2900
# Retrieved 100 articles at offset 2900. Total so far: 3000
# Retrieved 100 articles at offset 3000. Total so far: 3100
# Retrieved 100 articles at offset 3100. Total so far: 3200
# Retrieved 100 articles at offset 3200. Total so far: 3300
# Retrieved 100 articles at offset 3300. Total so far: 3400
# Retrieved 100 articles at offset 3400. Total so far: 3500
# Retrieved 100 articles at offset 3500. Total so far: 3600
# Retrieved 100 articles at offset 3600. Total so far: 3700
# Retrieved 100 articles at offset 3700. Total so far: 3800
# Retrieved 100 articles at offset 3800. Total so far: 3900
# Retrieved 100 articles at offset 3900. Total so far: 4000
# Retrieved 100 articles at offset 4000. Total so far: 4100
# Retrieved 100 articles at offset 4100. Total so far: 4200
# Retrieved 100 articles at offset 4200. Total so far: 4300
# Retrieved 100 articles at offset 4300. Total so far: 4400
# Retrieved 98 articles at offset 4400. Total so far: 4498
# Retrieved 100 articles at offset 4500. Total so far: 4598
# Retrieved 100 articles at offset 4600. Total so far: 4698
# Retrieved 100 articles at offset 4700. Total so far: 4798
# Retrieved 17 articles at offset 4800. Total so far: 4815
# Completed BA, Saved 4815 articles for Boeing → data/reuters_news/BA.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 100 articles at offset 700. Total so far: 800
# Retrieved 100 articles at offset 800. Total so far: 900
# Retrieved 100 articles at offset 900. Total so far: 1000
# Retrieved 100 articles at offset 1000. Total so far: 1100
# Retrieved 100 articles at offset 1100. Total so far: 1200
# Retrieved 100 articles at offset 1200. Total so far: 1300
# Retrieved 100 articles at offset 1300. Total so far: 1400
# Retrieved 100 articles at offset 1400. Total so far: 1500
# Retrieved 100 articles at offset 1500. Total so far: 1600
# Retrieved 100 articles at offset 1600. Total so far: 1700
# Retrieved 100 articles at offset 1700. Total so far: 1800
# Retrieved 100 articles at offset 1800. Total so far: 1900
# Retrieved 99 articles at offset 1900. Total so far: 1999
# Retrieved 100 articles at offset 2000. Total so far: 2099
# Retrieved 100 articles at offset 2100. Total so far: 2199
# Retrieved 100 articles at offset 2200. Total so far: 2299
# Retrieved 31 articles at offset 2300. Total so far: 2330
# Completed BAC, Saved 2330 articles for Bank of America → data/reuters_news/BAC.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 92 articles at offset 200. Total so far: 292
# Completed BK, Saved 292 articles for BNY Mellon → data/reuters_news/BK.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 70 articles at offset 100. Total so far: 170
# Completed BKNG, Saved 170 articles for Booking Holdings → data/reuters_news/BKNG.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 100 articles at offset 700. Total so far: 800
# Retrieved 100 articles at offset 800. Total so far: 900
# Retrieved 100 articles at offset 900. Total so far: 1000
# Retrieved 100 articles at offset 1000. Total so far: 1100
# Retrieved 100 articles at offset 1100. Total so far: 1200
# Retrieved 100 articles at offset 1200. Total so far: 1300
# Retrieved 100 articles at offset 1300. Total so far: 1400
# Retrieved 100 articles at offset 1400. Total so far: 1500
# Retrieved 100 articles at offset 1500. Total so far: 1600
# Retrieved 100 articles at offset 1600. Total so far: 1700
# Retrieved 100 articles at offset 1700. Total so far: 1800
# Retrieved 10 articles at offset 1800. Total so far: 1810
# Completed BLK, Saved 1810 articles for BlackRock → data/reuters_news/BLK.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 12 articles at offset 400. Total so far: 412
# Completed BMY, Saved 412 articles for Bristol Myers Squibb → data/reuters_news/BMY.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 100 articles at offset 700. Total so far: 800
# Retrieved 69 articles at offset 800. Total so far: 869
# Completed BRK.B, Saved 869 articles for Berkshire Hathaway → data/reuters_news/BRK.B.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 100 articles at offset 700. Total so far: 800
# Retrieved 100 articles at offset 800. Total so far: 900
# Retrieved 100 articles at offset 900. Total so far: 1000
# Retrieved 100 articles at offset 1000. Total so far: 1100
# Retrieved 100 articles at offset 1100. Total so far: 1200
# Retrieved 100 articles at offset 1200. Total so far: 1300
# Retrieved 100 articles at offset 1300. Total so far: 1400
# Retrieved 100 articles at offset 1400. Total so far: 1500
# Retrieved 100 articles at offset 1500. Total so far: 1600
# Retrieved 100 articles at offset 1600. Total so far: 1700
# Retrieved 100 articles at offset 1700. Total so far: 1800
# Retrieved 100 articles at offset 1800. Total so far: 1900
# Retrieved 100 articles at offset 1900. Total so far: 2000
# Retrieved 100 articles at offset 2000. Total so far: 2100
# Retrieved 100 articles at offset 2100. Total so far: 2200
# Retrieved 99 articles at offset 2200. Total so far: 2299
# Retrieved 99 articles at offset 2300. Total so far: 2398
# Retrieved 100 articles at offset 2400. Total so far: 2498
# Retrieved 100 articles at offset 2500. Total so far: 2598
# Retrieved 100 articles at offset 2600. Total so far: 2698
# Retrieved 100 articles at offset 2700. Total so far: 2798
# Retrieved 100 articles at offset 2800. Total so far: 2898
# Retrieved 100 articles at offset 2900. Total so far: 2998
# Retrieved 26 articles at offset 3000. Total so far: 3024
# Completed C, Saved 3024 articles for Citigroup → data/reuters_news/C.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 99 articles at offset 200. Total so far: 299
# Retrieved 48 articles at offset 300. Total so far: 347
# Completed CAT, Saved 347 articles for Caterpillar Inc → data/reuters_news/CAT.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 17 articles at offset 100. Total so far: 117
# Completed CHTR, Saved 117 articles for Charter Communications → data/reuters_news/CHTR.csv
# Retrieved 97 articles at offset 0. Total so far: 97
# Completed CL, Saved 97 articles for ColgatePalmolive → data/reuters_news/CL.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 99 articles at offset 600. Total so far: 699
# Retrieved 100 articles at offset 700. Total so far: 799
# Retrieved 8 articles at offset 800. Total so far: 807
# Completed CMCSA, Saved 807 articles for Comcast → data/reuters_news/CMCSA.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 61 articles at offset 100. Total so far: 161
# Completed COF, Saved 161 articles for Capital One → data/reuters_news/COF.csv
# No data to save for ConocoPhillips.
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 72 articles at offset 200. Total so far: 272
# Completed COST, Saved 272 articles for Costco → data/reuters_news/COST.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 9 articles at offset 400. Total so far: 409
# Completed CRM, Saved 409 articles for Salesforce → data/reuters_news/CRM.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 62 articles at offset 300. Total so far: 362
# Completed CSCO, Saved 362 articles for Cisco → data/reuters_news/CSCO.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 99 articles at offset 400. Total so far: 499
# Retrieved 98 articles at offset 500. Total so far: 597
# Retrieved 16 articles at offset 600. Total so far: 613
# Completed CVS, Saved 613 articles for CVS Health → data/reuters_news/CVS.csv
# No data to save for Chevron Corporation.
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 89 articles at offset 100. Total so far: 189
# Completed DE, Saved 189 articles for Deere Company → data/reuters_news/DE.csv
# Retrieved 98 articles at offset 0. Total so far: 98
# Completed DHR, Saved 98 articles for Danaher Corporation → data/reuters_news/DHR.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 100 articles at offset 700. Total so far: 800
# Retrieved 100 articles at offset 800. Total so far: 900
# Retrieved 100 articles at offset 900. Total so far: 1000
# Retrieved 100 articles at offset 1000. Total so far: 1100
# Retrieved 100 articles at offset 1100. Total so far: 1200
# Retrieved 100 articles at offset 1200. Total so far: 1300
# Retrieved 100 articles at offset 1300. Total so far: 1400
# Retrieved 100 articles at offset 1400. Total so far: 1500
# Retrieved 100 articles at offset 1500. Total so far: 1600
# Retrieved 99 articles at offset 1600. Total so far: 1699
# Retrieved 99 articles at offset 1700. Total so far: 1798
# Retrieved 100 articles at offset 1800. Total so far: 1898
# Retrieved 99 articles at offset 1900. Total so far: 1997
# Retrieved 62 articles at offset 2000. Total so far: 2059
# Completed DIS, Saved 2059 articles for Walt Disney Company → data/reuters_news/DIS.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 34 articles at offset 100. Total so far: 134
# Completed DUK, Saved 134 articles for Duke Energy → data/reuters_news/DUK.csv
# Retrieved 65 articles at offset 0. Total so far: 65
# Completed EMR, Saved 65 articles for Emerson Electric → data/reuters_news/EMR.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 99 articles at offset 100. Total so far: 199
# Retrieved 100 articles at offset 200. Total so far: 299
# Retrieved 100 articles at offset 300. Total so far: 399
# Retrieved 100 articles at offset 400. Total so far: 499
# Retrieved 100 articles at offset 500. Total so far: 599
# Retrieved 9 articles at offset 600. Total so far: 608
# Completed FDX, Saved 608 articles for FedEx → data/reuters_news/FDX.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 90 articles at offset 200. Total so far: 290
# Completed GD, Saved 290 articles for General Dynamics → data/reuters_news/GD.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 100 articles at offset 700. Total so far: 800
# Retrieved 99 articles at offset 800. Total so far: 899
# Retrieved 15 articles at offset 900. Total so far: 914
# Completed GE, Saved 914 articles for GE Aerospace → data/reuters_news/GE.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 89 articles at offset 300. Total so far: 389
# Completed GILD, Saved 389 articles for Gilead Sciences → data/reuters_news/GILD.csv
# No data to save for General Motors.
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 100 articles at offset 700. Total so far: 800
# Retrieved 100 articles at offset 800. Total so far: 900
# Retrieved 100 articles at offset 900. Total so far: 1000
# Retrieved 100 articles at offset 1000. Total so far: 1100
# Retrieved 100 articles at offset 1100. Total so far: 1200
# Retrieved 100 articles at offset 1200. Total so far: 1300
# Retrieved 100 articles at offset 1300. Total so far: 1400
# Retrieved 100 articles at offset 1400. Total so far: 1500
# Retrieved 100 articles at offset 1500. Total so far: 1600
# Retrieved 100 articles at offset 1600. Total so far: 1700
# Retrieved 100 articles at offset 1700. Total so far: 1800
# Retrieved 100 articles at offset 1800. Total so far: 1900
# Retrieved 100 articles at offset 1900. Total so far: 2000
# Retrieved 100 articles at offset 2000. Total so far: 2100
# Retrieved 100 articles at offset 2100. Total so far: 2200
# Retrieved 100 articles at offset 2200. Total so far: 2300
# Retrieved 100 articles at offset 2300. Total so far: 2400
# Retrieved 100 articles at offset 2400. Total so far: 2500
# Retrieved 100 articles at offset 2500. Total so far: 2600
# Retrieved 100 articles at offset 2600. Total so far: 2700
# Retrieved 100 articles at offset 2700. Total so far: 2800
# Retrieved 100 articles at offset 2800. Total so far: 2900
# Retrieved 100 articles at offset 2900. Total so far: 3000
# Retrieved 100 articles at offset 3000. Total so far: 3100
# Retrieved 100 articles at offset 3100. Total so far: 3200
# Retrieved 100 articles at offset 3200. Total so far: 3300
# Retrieved 100 articles at offset 3300. Total so far: 3400
# Retrieved 100 articles at offset 3400. Total so far: 3500
# Retrieved 100 articles at offset 3500. Total so far: 3600
# Retrieved 100 articles at offset 3600. Total so far: 3700
# Retrieved 100 articles at offset 3700. Total so far: 3800
# Retrieved 100 articles at offset 3800. Total so far: 3900
# Retrieved 99 articles at offset 3900. Total so far: 3999
# Retrieved 100 articles at offset 4000. Total so far: 4099
# Retrieved 100 articles at offset 4100. Total so far: 4199
# Retrieved 100 articles at offset 4200. Total so far: 4299
# Retrieved 100 articles at offset 4300. Total so far: 4399
# Retrieved 100 articles at offset 4400. Total so far: 4499
# Retrieved 100 articles at offset 4500. Total so far: 4599
# Retrieved 100 articles at offset 4600. Total so far: 4699
# Retrieved 100 articles at offset 4700. Total so far: 4799
# Retrieved 100 articles at offset 4800. Total so far: 4899
# Retrieved 100 articles at offset 4900. Total so far: 4999
# Retrieved 100 articles at offset 5000. Total so far: 5099
# Retrieved 100 articles at offset 5100. Total so far: 5199
# Retrieved 100 articles at offset 5200. Total so far: 5299
# Retrieved 100 articles at offset 5300. Total so far: 5399
# Retrieved 100 articles at offset 5400. Total so far: 5499
# Retrieved 99 articles at offset 5500. Total so far: 5598
# Retrieved 99 articles at offset 5600. Total so far: 5697
# Retrieved 100 articles at offset 5700. Total so far: 5797
# Retrieved 100 articles at offset 5800. Total so far: 5897
# Retrieved 99 articles at offset 5900. Total so far: 5996
# Retrieved 100 articles at offset 6000. Total so far: 6096
# Retrieved 100 articles at offset 6100. Total so far: 6196
# Retrieved 99 articles at offset 6200. Total so far: 6295
# Retrieved 100 articles at offset 6300. Total so far: 6395
# Retrieved 99 articles at offset 6400. Total so far: 6494
# Retrieved 100 articles at offset 6500. Total so far: 6594
# Retrieved 100 articles at offset 6600. Total so far: 6694
# Retrieved 100 articles at offset 6700. Total so far: 6794
# Retrieved 100 articles at offset 6800. Total so far: 6894
# Retrieved 99 articles at offset 6900. Total so far: 6993
# Retrieved 100 articles at offset 7000. Total so far: 7093
# Retrieved 100 articles at offset 7100. Total so far: 7193
# Retrieved 100 articles at offset 7200. Total so far: 7293
# Retrieved 100 articles at offset 7300. Total so far: 7393
# Retrieved 100 articles at offset 7400. Total so far: 7493
# Retrieved 100 articles at offset 7500. Total so far: 7593
# Retrieved 20 articles at offset 7600. Total so far: 7613
# Completed GOOGL, Saved 7613 articles for Alphabet Inc → data/reuters_news/GOOGL.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 100 articles at offset 700. Total so far: 800
# Retrieved 100 articles at offset 800. Total so far: 900
# Retrieved 100 articles at offset 900. Total so far: 1000
# Retrieved 100 articles at offset 1000. Total so far: 1100
# Retrieved 100 articles at offset 1100. Total so far: 1200
# Retrieved 100 articles at offset 1200. Total so far: 1300
# Retrieved 100 articles at offset 1300. Total so far: 1400
# Retrieved 100 articles at offset 1400. Total so far: 1500
# Retrieved 100 articles at offset 1500. Total so far: 1600
# Retrieved 100 articles at offset 1600. Total so far: 1700
# Retrieved 100 articles at offset 1700. Total so far: 1800
# Retrieved 100 articles at offset 1800. Total so far: 1900
# Retrieved 100 articles at offset 1900. Total so far: 2000
# Retrieved 100 articles at offset 2000. Total so far: 2100
# Retrieved 100 articles at offset 2100. Total so far: 2200
# Retrieved 100 articles at offset 2200. Total so far: 2300
# Retrieved 100 articles at offset 2300. Total so far: 2400
# Retrieved 100 articles at offset 2400. Total so far: 2500
# Retrieved 100 articles at offset 2500. Total so far: 2600
# Retrieved 99 articles at offset 2600. Total so far: 2699
# Retrieved 100 articles at offset 2700. Total so far: 2799
# Retrieved 100 articles at offset 2800. Total so far: 2899
# Retrieved 100 articles at offset 2900. Total so far: 2999
# Retrieved 99 articles at offset 3000. Total so far: 3098
# Retrieved 99 articles at offset 3100. Total so far: 3197
# Retrieved 99 articles at offset 3200. Total so far: 3296
# Retrieved 100 articles at offset 3300. Total so far: 3396
# Retrieved 100 articles at offset 3400. Total so far: 3496
# Retrieved 100 articles at offset 3500. Total so far: 3596
# Retrieved 100 articles at offset 3600. Total so far: 3696
# Retrieved 100 articles at offset 3700. Total so far: 3796
# Retrieved 100 articles at offset 3800. Total so far: 3896
# Retrieved 100 articles at offset 3900. Total so far: 3996
# Retrieved 46 articles at offset 4000. Total so far: 4042
# Completed GS, Saved 4042 articles for Goldman Sachs → data/reuters_news/GS.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 29 articles at offset 400. Total so far: 429
# Completed HD, Saved 429 articles for Home Depot → data/reuters_news/HD.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 91 articles at offset 200. Total so far: 291
# Completed HON, Saved 291 articles for Honeywell → data/reuters_news/HON.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 22 articles at offset 500. Total so far: 522
# Completed IBM, Saved 522 articles for IBM → data/reuters_news/IBM.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 100 articles at offset 700. Total so far: 800
# Retrieved 100 articles at offset 800. Total so far: 900
# Retrieved 100 articles at offset 900. Total so far: 1000
# Retrieved 100 articles at offset 1000. Total so far: 1100
# Retrieved 100 articles at offset 1100. Total so far: 1200
# Retrieved 100 articles at offset 1200. Total so far: 1300
# Retrieved 100 articles at offset 1300. Total so far: 1400
# Retrieved 100 articles at offset 1400. Total so far: 1500
# Retrieved 100 articles at offset 1500. Total so far: 1600
# Retrieved 98 articles at offset 1600. Total so far: 1698
# Retrieved 100 articles at offset 1700. Total so far: 1798
# Retrieved 100 articles at offset 1800. Total so far: 1898
# Retrieved 41 articles at offset 1900. Total so far: 1939
# Completed INTC, Saved 1939 articles for Intel → data/reuters_news/INTC.csv
# Retrieved 75 articles at offset 0. Total so far: 75
# Completed INTU, Saved 75 articles for Intuit → data/reuters_news/INTU.csv
# Retrieved 54 articles at offset 0. Total so far: 54
# Completed ISRG, Saved 54 articles for Intuitive Surgical → data/reuters_news/ISRG.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 99 articles at offset 300. Total so far: 399
# Retrieved 100 articles at offset 400. Total so far: 499
# Retrieved 100 articles at offset 500. Total so far: 599
# Retrieved 100 articles at offset 600. Total so far: 699
# Retrieved 99 articles at offset 700. Total so far: 798
# Retrieved 100 articles at offset 800. Total so far: 898
# Retrieved 100 articles at offset 900. Total so far: 998
# Retrieved 99 articles at offset 1000. Total so far: 1097
# Retrieved 100 articles at offset 1100. Total so far: 1197
# Retrieved 100 articles at offset 1200. Total so far: 1297
# Retrieved 100 articles at offset 1300. Total so far: 1397
# Retrieved 100 articles at offset 1400. Total so far: 1497
# Retrieved 100 articles at offset 1500. Total so far: 1597
# Retrieved 100 articles at offset 1600. Total so far: 1697
# Retrieved 100 articles at offset 1700. Total so far: 1797
# Retrieved 100 articles at offset 1800. Total so far: 1897
# Retrieved 100 articles at offset 1900. Total so far: 1997
# Retrieved 100 articles at offset 2000. Total so far: 2097
# Retrieved 100 articles at offset 2100. Total so far: 2197
# Retrieved 3 articles at offset 2200. Total so far: 2200
# Completed JNJ, Saved 2200 articles for Johnson Johnson → data/reuters_news/JNJ.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 100 articles at offset 700. Total so far: 800
# Retrieved 100 articles at offset 800. Total so far: 900
# Retrieved 100 articles at offset 900. Total so far: 1000
# Retrieved 100 articles at offset 1000. Total so far: 1100
# Retrieved 100 articles at offset 1100. Total so far: 1200
# Retrieved 100 articles at offset 1200. Total so far: 1300
# Retrieved 100 articles at offset 1300. Total so far: 1400
# Retrieved 100 articles at offset 1400. Total so far: 1500
# Retrieved 100 articles at offset 1500. Total so far: 1600
# Retrieved 100 articles at offset 1600. Total so far: 1700
# Retrieved 100 articles at offset 1700. Total so far: 1800
# Retrieved 100 articles at offset 1800. Total so far: 1900
# Retrieved 100 articles at offset 1900. Total so far: 2000
# Retrieved 100 articles at offset 2000. Total so far: 2100
# Retrieved 100 articles at offset 2100. Total so far: 2200
# Retrieved 100 articles at offset 2200. Total so far: 2300
# Retrieved 100 articles at offset 2300. Total so far: 2400
# Retrieved 100 articles at offset 2400. Total so far: 2500
# Retrieved 100 articles at offset 2500. Total so far: 2600
# Retrieved 100 articles at offset 2600. Total so far: 2700
# Retrieved 100 articles at offset 2700. Total so far: 2800
# Retrieved 100 articles at offset 2800. Total so far: 2900
# Retrieved 100 articles at offset 2900. Total so far: 3000
# Retrieved 100 articles at offset 3000. Total so far: 3100
# Retrieved 100 articles at offset 3100. Total so far: 3200
# Retrieved 100 articles at offset 3200. Total so far: 3300
# Retrieved 99 articles at offset 3300. Total so far: 3399
# Retrieved 99 articles at offset 3400. Total so far: 3498
# Retrieved 100 articles at offset 3500. Total so far: 3598
# Retrieved 100 articles at offset 3600. Total so far: 3698
# Retrieved 100 articles at offset 3700. Total so far: 3798
# Retrieved 100 articles at offset 3800. Total so far: 3898
# Retrieved 100 articles at offset 3900. Total so far: 3998
# Retrieved 100 articles at offset 4000. Total so far: 4098
# Retrieved 100 articles at offset 4100. Total so far: 4198
# Retrieved 11 articles at offset 4200. Total so far: 4209
# Completed JPM, Saved 4209 articles for JPMorgan Chase → data/reuters_news/JPM.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 91 articles at offset 500. Total so far: 591
# Completed KO, Saved 591 articles for CocaCola Company → data/reuters_news/KO.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 2 articles at offset 100. Total so far: 102
# Completed LIN, Saved 102 articles for Linde plc → data/reuters_news/LIN.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 100 articles at offset 700. Total so far: 800
# Retrieved 100 articles at offset 800. Total so far: 900
# Retrieved 100 articles at offset 900. Total so far: 1000
# Retrieved 100 articles at offset 1000. Total so far: 1100
# Retrieved 100 articles at offset 1100. Total so far: 1200
# Retrieved 100 articles at offset 1200. Total so far: 1300
# Retrieved 100 articles at offset 1300. Total so far: 1400
# Retrieved 100 articles at offset 1400. Total so far: 1500
# Retrieved 60 articles at offset 1500. Total so far: 1560
# Completed LLY, Saved 1560 articles for Eli Lilly and Company → data/reuters_news/LLY.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 100 articles at offset 700. Total so far: 800
# Retrieved 100 articles at offset 800. Total so far: 900
# Retrieved 100 articles at offset 900. Total so far: 1000
# Retrieved 100 articles at offset 1000. Total so far: 1100
# Retrieved 100 articles at offset 1100. Total so far: 1200
# Retrieved 29 articles at offset 1200. Total so far: 1229
# Completed LMT, Saved 1229 articles for Lockheed Martin → data/reuters_news/LMT.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 20 articles at offset 200. Total so far: 220
# Completed LOW, Saved 220 articles for Lowes → data/reuters_news/LOW.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 99 articles at offset 400. Total so far: 499
# Retrieved 58 articles at offset 500. Total so far: 557
# Completed MA, Saved 557 articles for Mastercard → data/reuters_news/MA.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 100 articles at offset 700. Total so far: 800
# Retrieved 13 articles at offset 800. Total so far: 813
# Completed MCD, Saved 813 articles for McDonalds → data/reuters_news/MCD.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 60 articles at offset 200. Total so far: 260
# Completed MDLZ, Saved 260 articles for Mondelēz International → data/reuters_news/MDLZ.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 31 articles at offset 100. Total so far: 131
# Completed MDT, Saved 131 articles for Medtronic → data/reuters_news/MDT.csv
# Retrieved 71 articles at offset 0. Total so far: 71
# Completed MET, Saved 71 articles for MetLife → data/reuters_news/MET.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 100 articles at offset 700. Total so far: 800
# Retrieved 100 articles at offset 800. Total so far: 900
# Retrieved 100 articles at offset 900. Total so far: 1000
# Retrieved 100 articles at offset 1000. Total so far: 1100
# Retrieved 100 articles at offset 1100. Total so far: 1200
# Retrieved 100 articles at offset 1200. Total so far: 1300
# Retrieved 100 articles at offset 1300. Total so far: 1400
# Retrieved 100 articles at offset 1400. Total so far: 1500
# Retrieved 100 articles at offset 1500. Total so far: 1600
# Retrieved 100 articles at offset 1600. Total so far: 1700
# Retrieved 100 articles at offset 1700. Total so far: 1800
# Retrieved 100 articles at offset 1800. Total so far: 1900
# Retrieved 100 articles at offset 1900. Total so far: 2000
# Retrieved 100 articles at offset 2000. Total so far: 2100
# Retrieved 100 articles at offset 2100. Total so far: 2200
# Retrieved 100 articles at offset 2200. Total so far: 2300
# Retrieved 100 articles at offset 2300. Total so far: 2400
# Retrieved 100 articles at offset 2400. Total so far: 2500
# Retrieved 100 articles at offset 2500. Total so far: 2600
# Retrieved 100 articles at offset 2600. Total so far: 2700
# Retrieved 100 articles at offset 2700. Total so far: 2800
# Retrieved 100 articles at offset 2800. Total so far: 2900
# Retrieved 100 articles at offset 2900. Total so far: 3000
# Retrieved 100 articles at offset 3000. Total so far: 3100
# Retrieved 100 articles at offset 3100. Total so far: 3200
# Retrieved 100 articles at offset 3200. Total so far: 3300
# Retrieved 100 articles at offset 3300. Total so far: 3400
# Retrieved 100 articles at offset 3400. Total so far: 3500
# Retrieved 100 articles at offset 3500. Total so far: 3600
# Retrieved 100 articles at offset 3600. Total so far: 3700
# Retrieved 100 articles at offset 3700. Total so far: 3800
# Retrieved 100 articles at offset 3800. Total so far: 3900
# Retrieved 100 articles at offset 3900. Total so far: 4000
# Retrieved 100 articles at offset 4000. Total so far: 4100
# Retrieved 100 articles at offset 4100. Total so far: 4200
# Retrieved 100 articles at offset 4200. Total so far: 4300
# Retrieved 99 articles at offset 4300. Total so far: 4399
# Retrieved 100 articles at offset 4400. Total so far: 4499
# Retrieved 100 articles at offset 4500. Total so far: 4599
# Retrieved 99 articles at offset 4600. Total so far: 4698
# Retrieved 100 articles at offset 4700. Total so far: 4798
# Retrieved 100 articles at offset 4800. Total so far: 4898
# Retrieved 97 articles at offset 4900. Total so far: 4995
# Retrieved 80 articles at offset 5000. Total so far: 5075
# Completed META, Saved 5075 articles for Meta Platforms → data/reuters_news/META.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 84 articles at offset 200. Total so far: 284
# Completed MMM, Saved 284 articles for 3M → data/reuters_news/MMM.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 51 articles at offset 100. Total so far: 151
# Completed MO, Saved 151 articles for Altria → data/reuters_news/MO.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 100 articles at offset 700. Total so far: 800
# Retrieved 99 articles at offset 800. Total so far: 899
# Retrieved 100 articles at offset 900. Total so far: 999
# Retrieved 10 articles at offset 1000. Total so far: 1009
# Completed MRK, Saved 1009 articles for Merck Co → data/reuters_news/MRK.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 100 articles at offset 700. Total so far: 800
# Retrieved 100 articles at offset 800. Total so far: 900
# Retrieved 100 articles at offset 900. Total so far: 1000
# Retrieved 100 articles at offset 1000. Total so far: 1100
# Retrieved 100 articles at offset 1100. Total so far: 1200
# Retrieved 100 articles at offset 1200. Total so far: 1300
# Retrieved 100 articles at offset 1300. Total so far: 1400
# Retrieved 100 articles at offset 1400. Total so far: 1500
# Retrieved 99 articles at offset 1500. Total so far: 1599
# Retrieved 100 articles at offset 1600. Total so far: 1699
# Retrieved 100 articles at offset 1700. Total so far: 1799
# Retrieved 100 articles at offset 1800. Total so far: 1899
# Retrieved 100 articles at offset 1900. Total so far: 1999
# Retrieved 100 articles at offset 2000. Total so far: 2099
# Retrieved 100 articles at offset 2100. Total so far: 2199
# Retrieved 100 articles at offset 2200. Total so far: 2299
# Retrieved 14 articles at offset 2300. Total so far: 2313
# Completed MS, Saved 2313 articles for Morgan Stanley → data/reuters_news/MS.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 100 articles at offset 700. Total so far: 800
# Retrieved 100 articles at offset 800. Total so far: 900
# Retrieved 100 articles at offset 900. Total so far: 1000
# Retrieved 100 articles at offset 1000. Total so far: 1100
# Retrieved 100 articles at offset 1100. Total so far: 1200
# Retrieved 100 articles at offset 1200. Total so far: 1300
# Retrieved 100 articles at offset 1300. Total so far: 1400
# Retrieved 100 articles at offset 1400. Total so far: 1500
# Retrieved 100 articles at offset 1500. Total so far: 1600
# Retrieved 100 articles at offset 1600. Total so far: 1700
# Retrieved 100 articles at offset 1700. Total so far: 1800
# Retrieved 100 articles at offset 1800. Total so far: 1900
# Retrieved 99 articles at offset 1900. Total so far: 1999
# Retrieved 100 articles at offset 2000. Total so far: 2099
# Retrieved 100 articles at offset 2100. Total so far: 2199
# Retrieved 100 articles at offset 2200. Total so far: 2299
# Retrieved 100 articles at offset 2300. Total so far: 2399
# Retrieved 100 articles at offset 2400. Total so far: 2499
# Retrieved 100 articles at offset 2500. Total so far: 2599
# Retrieved 100 articles at offset 2600. Total so far: 2699
# Retrieved 100 articles at offset 2700. Total so far: 2799
# Retrieved 100 articles at offset 2800. Total so far: 2899
# Retrieved 100 articles at offset 2900. Total so far: 2999
# ...
# Retrieved 99 articles at offset 2900. Total so far: 2993
# Retrieved 100 articles at offset 3000. Total so far: 3093
# Retrieved 100 articles at offset 3100. Total so far: 3193
# Retrieved 100 articles at offset 3200. Total so far: 3293
# Retrieved 100 articles at offset 3300. Total so far: 3393
# Retrieved 100 articles at offset 3400. Total so far: 3493
# Retrieved 100 articles at offset 3500. Total so far: 3593
# Retrieved 100 articles at offset 3600. Total so far: 3693
# Retrieved 100 articles at offset 3700. Total so far: 3793
# Retrieved 100 articles at offset 3800. Total so far: 3893
# Retrieved 100 articles at offset 3900. Total so far: 3993
# Retrieved 100 articles at offset 4000. Total so far: 4093
# Retrieved 100 articles at offset 4100. Total so far: 4193
# Retrieved 100 articles at offset 4200. Total so far: 4293
# Retrieved 100 articles at offset 4300. Total so far: 4393
# Retrieved 100 articles at offset 4400. Total so far: 4493
# Retrieved 100 articles at offset 4500. Total so far: 4593
# Retrieved 100 articles at offset 4600. Total so far: 4693
# Retrieved 100 articles at offset 4700. Total so far: 4793
# Retrieved 100 articles at offset 4800. Total so far: 4893
# Retrieved 100 articles at offset 4900. Total so far: 4993
# Retrieved 100 articles at offset 5000. Total so far: 5093
# Retrieved 100 articles at offset 5100. Total so far: 5193
# Retrieved 25 articles at offset 5200. Total so far: 5218
# Completed PFE, Saved 5218 articles for Pfizer → data/reuters_news/PFE.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Completed PG, Saved 100 articles for Procter Gamble → data/reuters_news/PG.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 93 articles at offset 200. Total so far: 293
# Completed PLTR, Saved 293 articles for Palantir Technologies → data/reuters_news/PLTR.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 51 articles at offset 200. Total so far: 251
# Completed PM, Saved 251 articles for Philip Morris International → data/reuters_news/PM.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 96 articles at offset 400. Total so far: 496
# Completed PYPL, Saved 496 articles for PayPal → data/reuters_news/PYPL.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 99 articles at offset 600. Total so far: 699
# Retrieved 100 articles at offset 700. Total so far: 799
# Retrieved 88 articles at offset 800. Total so far: 887
# Completed QCOM, Saved 887 articles for Qualcomm → data/reuters_news/QCOM.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 20 articles at offset 500. Total so far: 520
# Completed RTX, Saved 520 articles for RTX Corporation → data/reuters_news/RTX.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 100 articles at offset 700. Total so far: 800
# Completed SBUX, Saved 800 articles for Starbucks → data/reuters_news/SBUX.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 39 articles at offset 200. Total so far: 239
# Completed SCHW, Saved 239 articles for Charles Schwab Corporation → data/reuters_news/SCHW.csv
# Retrieved 87 articles at offset 0. Total so far: 87
# Completed SO, Saved 87 articles for Southern Company → data/reuters_news/SO.csv
# Retrieved 67 articles at offset 0. Total so far: 67
# Completed SPG, Saved 67 articles for Simon Property Group → data/reuters_news/SPG.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 99 articles at offset 500. Total so far: 599
# Retrieved 100 articles at offset 600. Total so far: 699
# Retrieved 100 articles at offset 700. Total so far: 799
# Retrieved 87 articles at offset 800. Total so far: 886
# Completed T, Saved 886 articles for ATT → data/reuters_news/T.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 100 articles at offset 700. Total so far: 800
# Retrieved 100 articles at offset 800. Total so far: 900
# Retrieved 87 articles at offset 900. Total so far: 987
# Completed TGT, Saved 987 articles for Target Corporation → data/reuters_news/TGT.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 73 articles at offset 100. Total so far: 173
# Completed TMO, Saved 173 articles for Thermo Fisher Scientific → data/reuters_news/TMO.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 16 articles at offset 400. Total so far: 416
# Completed TMUS, Saved 416 articles for TMobile US → data/reuters_news/TMUS.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 100 articles at offset 700. Total so far: 800
# Retrieved 100 articles at offset 800. Total so far: 900
# Retrieved 100 articles at offset 900. Total so far: 1000
# Retrieved 100 articles at offset 1000. Total so far: 1100
# Retrieved 100 articles at offset 1100. Total so far: 1200
# Retrieved 100 articles at offset 1200. Total so far: 1300
# Retrieved 100 articles at offset 1300. Total so far: 1400
# Retrieved 100 articles at offset 1400. Total so far: 1500
# Retrieved 100 articles at offset 1500. Total so far: 1600
# Retrieved 100 articles at offset 1600. Total so far: 1700
# Retrieved 100 articles at offset 1700. Total so far: 1800
# Retrieved 100 articles at offset 1800. Total so far: 1900
# Retrieved 100 articles at offset 1900. Total so far: 2000
# Retrieved 100 articles at offset 2000. Total so far: 2100
# Retrieved 100 articles at offset 2100. Total so far: 2200
# Retrieved 100 articles at offset 2200. Total so far: 2300
# Retrieved 100 articles at offset 2300. Total so far: 2400
# Retrieved 100 articles at offset 2400. Total so far: 2500
# Retrieved 100 articles at offset 2500. Total so far: 2600
# Retrieved 100 articles at offset 2600. Total so far: 2700
# Retrieved 100 articles at offset 2700. Total so far: 2800
# Retrieved 100 articles at offset 2800. Total so far: 2900
# Retrieved 100 articles at offset 2900. Total so far: 3000
# Retrieved 100 articles at offset 3000. Total so far: 3100
# Retrieved 100 articles at offset 3100. Total so far: 3200
# Retrieved 100 articles at offset 3200. Total so far: 3300
# Retrieved 100 articles at offset 3300. Total so far: 3400
# Retrieved 100 articles at offset 3400. Total so far: 3500
# Retrieved 100 articles at offset 3500. Total so far: 3600
# Retrieved 99 articles at offset 3600. Total so far: 3699
# Retrieved 100 articles at offset 3700. Total so far: 3799
# Retrieved 100 articles at offset 3800. Total so far: 3899
# Retrieved 100 articles at offset 3900. Total so far: 3999
# Retrieved 100 articles at offset 4000. Total so far: 4099
# Retrieved 100 articles at offset 4100. Total so far: 4199
# Retrieved 100 articles at offset 4200. Total so far: 4299
# Retrieved 100 articles at offset 4300. Total so far: 4399
# Retrieved 100 articles at offset 4400. Total so far: 4499
# Retrieved 100 articles at offset 4500. Total so far: 4599
# Retrieved 100 articles at offset 4600. Total so far: 4699
# Retrieved 100 articles at offset 4700. Total so far: 4799
# Retrieved 100 articles at offset 4800. Total so far: 4899
# Retrieved 100 articles at offset 4900. Total so far: 4999
# Retrieved 99 articles at offset 5000. Total so far: 5098
# Retrieved 100 articles at offset 5100. Total so far: 5198
# Retrieved 100 articles at offset 5200. Total so far: 5298
# Retrieved 100 articles at offset 5300. Total so far: 5398
# Retrieved 100 articles at offset 5400. Total so far: 5498
# Retrieved 100 articles at offset 5500. Total so far: 5598
# Retrieved 100 articles at offset 5600. Total so far: 5698
# Retrieved 100 articles at offset 5700. Total so far: 5798
# Retrieved 100 articles at offset 5800. Total so far: 5898
# Retrieved 100 articles at offset 5900. Total so far: 5998
# Retrieved 100 articles at offset 6000. Total so far: 6098
# Retrieved 100 articles at offset 6100. Total so far: 6198
# Retrieved 99 articles at offset 6200. Total so far: 6297
# Retrieved 100 articles at offset 6300. Total so far: 6397
# Retrieved 100 articles at offset 6400. Total so far: 6497
# Retrieved 100 articles at offset 6500. Total so far: 6597
# Retrieved 100 articles at offset 6600. Total so far: 6697
# Retrieved 100 articles at offset 6700. Total so far: 6797
# Retrieved 100 articles at offset 6800. Total so far: 6897
# Retrieved 99 articles at offset 6900. Total so far: 6996
# Retrieved 99 articles at offset 7000. Total so far: 7095
# Retrieved 97 articles at offset 7100. Total so far: 7192
# Retrieved 100 articles at offset 7200. Total so far: 7292
# Retrieved 99 articles at offset 7300. Total so far: 7391
# Retrieved 99 articles at offset 7400. Total so far: 7490
# Retrieved 98 articles at offset 7500. Total so far: 7588
# Retrieved 100 articles at offset 7600. Total so far: 7688
# Retrieved 99 articles at offset 7700. Total so far: 7787
# Retrieved 100 articles at offset 7800. Total so far: 7887
# Retrieved 99 articles at offset 7900. Total so far: 7986
# Retrieved 99 articles at offset 8000. Total so far: 8085
# Retrieved 100 articles at offset 8100. Total so far: 8185
# Retrieved 100 articles at offset 8200. Total so far: 8285
# Retrieved 100 articles at offset 8300. Total so far: 8385
# Retrieved 100 articles at offset 8400. Total so far: 8485
# Retrieved 61 articles at offset 8500. Total so far: 8546
# Completed TSLA, Saved 8546 articles for Tesla Inc → data/reuters_news/TSLA.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 6 articles at offset 200. Total so far: 206
# Completed TXN, Saved 206 articles for Texas Instruments → data/reuters_news/TXN.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 10 articles at offset 700. Total so far: 710
# Completed UNH, Saved 710 articles for UnitedHealth Group → data/reuters_news/UNH.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 43 articles at offset 200. Total so far: 243
# Completed UNP, Saved 243 articles for Union Pacific Corporation → data/reuters_news/UNP.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 54 articles at offset 500. Total so far: 554
# Completed UPS, Saved 554 articles for United Parcel Service → data/reuters_news/UPS.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 80 articles at offset 100. Total so far: 180
# Completed USB, Saved 180 articles for US Bancorp → data/reuters_news/USB.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 89 articles at offset 500. Total so far: 589
# Completed V, Saved 589 articles for Visa Inc → data/reuters_news/V.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 98 articles at offset 500. Total so far: 598
# Retrieved 51 articles at offset 600. Total so far: 649
# Completed VZ, Saved 649 articles for Verizon → data/reuters_news/VZ.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Completed WFC, Saved 700 articles for Wells Fargo → data/reuters_news/WFC.csv
# Retrieved 100 articles at offset 0. Total so far: 100
# Retrieved 100 articles at offset 100. Total so far: 200
# Retrieved 100 articles at offset 200. Total so far: 300
# Retrieved 100 articles at offset 300. Total so far: 400
# Retrieved 100 articles at offset 400. Total so far: 500
# Retrieved 100 articles at offset 500. Total so far: 600
# Retrieved 100 articles at offset 600. Total so far: 700
# Retrieved 100 articles at offset 700. Total so far: 800
# Retrieved 100 articles at offset 800. Total so far: 900
# Retrieved 100 articles at offset 900. Total so far: 1000
# Retrieved 100 articles at offset 1000. Total so far: 1100
# Retrieved 100 articles at offset 1100. Total so far: 1200
# Retrieved 100 articles at offset 1200. Total so far: 1300
# Retrieved 100 articles at offset 1300. Total so far: 1400
# Retrieved 100 articles at offset 1400. Total so far: 1500
# Retrieved 100 articles at offset 1500. Total so far: 1600
# Retrieved 100 articles at offset 1600. Total so far: 1700
# Retrieved 100 articles at offset 1700. Total so far: 1800
# Retrieved 100 articles at offset 1800. Total so far: 1900
# Retrieved 100 articles at offset 1900. Total so far: 2000
# Retrieved 100 articles at offset 2000. Total so far: 2100
# Retrieved 100 articles at offset 2100. Total so far: 2200
# Retrieved 100 articles at offset 2200. Total so far: 2300
# Retrieved 100 articles at offset 2300. Total so far: 2400
# Retrieved 100 articles at offset 2400. Total so far: 2500
# Retrieved 85 articles at offset 2500. Total so far: 2585
# Completed WMT, Saved 2585 articles for Walmart → data/reuters_news/WMT.csv
# Retrieved 44 articles at offset 0. Total so far: 44
# Completed XOM, Saved 44 articles for ExxonMobil → data/reuters_news/XOM.csv
